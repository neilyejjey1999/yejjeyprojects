# %% [markdown]
# <h2>FIN5622 Project #6
#     <p class="text-primary">Stock Price Prediction with Machine Learning</p>
# </h2>

# %% [markdown]
# <div class = "panel panel-success">
#     <div class = "panel-heading">
#     <span style="color:black"><b>Project Introduction</b>
#     </div>
#     <div class = "panel-body">
#     In this project we will compare the performance of a linear regression model against a neural network in predicting the stock returns of Apple using the 5 Fama-French Factors as explanatory variables.
#     </div>
# </div>
#
# <div class = "panel panel-info">
#     <div class = "panel-heading">
#     <span style="color:black"><b>Instructions</b>
#     </div>
#     <div class = "panel-body">
#     Please code you solutions directly in this Notebook under each task in the cells provided below. Tasks are intended to be done in order with results from one task informing work in later tasks. Include all code used to produce your results, and support your answers with textual explanations if neccessary. <b>Any written text must be typed in a markdown cell to receive credit!</b> You may feel free to add additional Code and/or Markdown cells as needed. Code must be written using <b>Python 3</b>.
#     <br><br>Please order the cells in your Notebook in the order in which they are intended to run! It is expected that your Notebook is able to run in sequence from start to finish without any errors (before submitting check by: <code>Kernel > Restart & Run All</code>).
#     <br><br>Once ready, please submit your assignment as an <b>.ipynb file</b> (<code>File > Download as > Notebook</code>). You must name your files in the following format: <b><code>FIN5622_Project_6_Richard_Lee_tuc12345.ipynb</code></b>.
#     </div>
# </div>
#
# ---
# <div class = "alert alert-block alert-warning">
#     <b>Note</b>: Import all libraries that you plan on using in the code block below.
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.api import OLS, add_constant
import tensorflow as tf
print("TensorFlow version:", tf.__version__) #Check Tensorflow version is at least 2.8!
# Out:
# TensorFlow version: 2.8.0

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 1</b>
#     </div>
#     <div class = "panel-body">
#     The dataset "Fama_French_5_Factors_Daily.csv" contains pre-constructed factors for the Fama-French Models developed by economists Eugene Fama and Kenneth French. They include daily time series of the following risk factors:
#     <br>
#     <ul>
#         <li><b>ERP</b> (Equity Risk Premium): Excess return of market over risk-free rate.</li>
#         <li><b>SMB</b> (Small Minus Big): Excess returns of small market cap firms over large cap firms.</li>
#         <li><b>HML</b> (High Minus Low):  Excess returns of high Book-to-Market ratio firms over low firms.</li>
#         <li><b>RMW</b> (Robust Minus Weak): Excess returns of profitable firms over least profitable firms.</li>
#         <li><b>CMA</b> (Conservative Minus Aggressive): Excess return of conservative firms over aggressive firms.</li>
#         <li><b>RF</b> (Risk-free Rate): Proxied by the 1-month Treasury rate.</li>
#     </ul>
#     These 5 factors when used in econometric regression of historical stock prices forms the asset valuation model known as the Fama-French 5-Factor Model. The file "AAPL.csv" contains only two columns, "Date" and "Price", which represents the daily stock price for Apple. We will use these 5-factors to build an asset valuation model for Apple stock.
#     <br><br>
#     Read in the datasets "Fama_French_5_Factors_Daily.csv" and "AAPL.csv" into dataframes using the pandas <code>pd.read_csv()</code> function, as well as set the "Date" column as the index, and make sure to set <code>parse_dates = ['Date']</code>. Combine the two DataFrames into a single DataFrame, keeping only the dates where there are observations under both datasets. Store this in a variable called <code>data</code>.
#     <br><br>
#     Calculate the daily log-returns of AAPL, and store this in <code>data</code> as a new column called <code>Returns</code>. Next subtract from <code>Returns</code> the risk-free rate in column <code>RF</code>, and store this result in <code>data</code> as a new column called <code>ExcessReturns</code>. Drop any rows in <code>data</code> containing missing values, or <code>NaN</code>'s.
#     <br><br>
#     Your final DataFrame should have 9928 rows and 9 columns, and look like this:
#
# ![Task_1_Data.JPG](attachment:Task_1_Data.JPG)
#     <p style="text-align:right;">[10pts]</p>
#     </div>
# </div>

# %%
data = pd.read_csv('Fama_French_5_Factors_Daily.csv', 
                   index_col = 'Date', parse_dates = ['Date'])
AAPL = pd.read_csv('AAPL.csv', index_col = 'Date', parse_dates = ['Date'], 
                   usecols = ['Date', 'Price'])
data = pd.concat((data, AAPL), axis = 1)
data['Returns'] = np.log(1. + data['Price'].pct_change()) * 100.
data['ExcessReturns'] = data['Returns'] - data['RF']
data = data.dropna()
data
# Out:
#              ERP   SMB   HML   RMW   CMA     RF       Price   Returns  \
# Date
# 1980-12-15  0.11  0.20 -0.49  0.35 -0.37  0.059    0.384517 -5.358407
# 1980-12-16  0.71 -0.76 -0.47  0.47 -0.28  0.059    0.356296 -7.622616
# 1980-12-17  1.52 -0.73 -0.34  0.11 -0.41  0.059    0.365115  2.445053
# 1980-12-18  0.41  0.34  1.27 -1.13  0.27  0.059    0.375698  2.857326
# 1980-12-19  0.58  0.21  0.60 -0.52  0.40  0.059    0.398628  5.924302
# ...          ...   ...   ...   ...   ...    ...         ...       ...
# 2020-04-24  1.44  0.29 -0.09 -0.14  0.16  0.000  282.206085  2.846075
# 2020-04-27  1.73  2.20  2.74 -0.12  0.20  0.000  282.405548  0.070655
# 2020-04-28 -0.44  1.65  2.89  1.39  0.74  0.000  277.827911 -1.634225
# 2020-04-29  2.92  2.27  2.04  1.22 -0.81  0.000  286.953247  3.231740
# 2020-04-30 -1.18 -2.06 -1.63  0.71 -0.10  0.000  293.006836  2.087664
#
#             ExcessReturns
# Date
# 1980-12-15      -5.417407
# 1980-12-16      -7.681616
# 1980-12-17       2.386053
# 1980-12-18       2.798326
# 1980-12-19       5.865302
# ...                   ...
# 2020-04-24       2.846075
# 2020-04-27       0.070655
# 2020-04-28      -1.634225
# 2020-04-29       3.231740
# 2020-04-30       2.087664
#
# [9928 rows x 9 columns]

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 2</b>
#     </div>
#     <div class = "panel-body">
#     We will predict the target variable "ExcessReturns" (representing the excess return above the risk-free rate on Apple stock) using the 5 Fama-French factors as our explanatory variables. For conveniance, create a variable with the list of the columns names: <code>factors = ['ERP', 'SMB', 'HML', 'RMW', 'CMA']</code>.
#     <br><br>
#     Next we will split <code>data</code> into training and test datasets. Specifically, store all observations prior to the date '2019-04-30' in a variable called <code>train_data</code>, and all observations afterwards in a variable called <code>test_data</code>.
#     Check that each DataFrame shoud have the following shapes:
#     <ul>
#         <li><code>train_data.shape = (9675, 9)</code></li>
#         <li><code>test_data.shape = (254, 9)</code></li>
#     </ul>
#     <p style="text-align:right;">[5pts]</p>
#     </div>
# </div>

# %%
factors = ['ERP', 'SMB', 'HML', 'RMW', 'CMA']
train_data = data.loc[:'2019-04-30'].copy()
test_data = data.loc['2019-04-30':].copy()

# %%
train_data.shape
# Out:
# (9675, 9)

# %%
test_data.shape
# Out:
# (254, 9)

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 3</b>
#     </div>
#     <div class = "panel-body">
#     Fit a linear regression model on <code>train_data</code>, predicting <code>'ExcessReturns'</code> using the 5 Fama-French factors in <code>factors</code>. Remember to add a constant to the explanatory variables in order to fit the intercept. Store this model in a variable called <code>lin_model</code>.
#     <br><br>
#     Print the beta coefficients of the model. For each coefficient, comment on whether the sign (positive or negative) is as expected. Explain why or why not.
#     <p style="text-align:right;">[10pts]</p>
#     </div>
# </div>

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression().fit(train_data[factors], train_data['ExcessReturns'])

# %%
lin_model.coef_
# Out:
# array([ 1.08732586, -0.08829506, -0.48891268, -0.15549496, -1.02069132])

# %% [markdown]
# ERP being a positive 1.08732586 is expected, due to the increasing risk having a sybiotic relationship with stock price (positive risk drives up stock price).
#
# SMB being negative -0.08829506 is expected, as AAPL is a large company and would likely have more large cap returns than small cap returns, as evident by this value.
#
# HML being -0.48891268 is similar to the previous answer, as large firms are have a lower value of B/P when compared to small firms.  This negative value illustrates this point.
#
# RMW being negative (-0.15549496) is unexpected, as this should be positive as its a measure of how higher earning firms achieve profitability over lower earning firms. Despite AAPL being a high earning firm, it is evident that this negative value is unexepected as being a high earning firm should make AAPL have a positive RMW.
#
# CMA being a negative -1.02069132 is expected, as in this situation all of the firms that were aggresively investing were profiting, while to converse was evident.  This value further illustrates that data point.

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 4</b>
#     </div>
#     <div class = "panel-body">
#     Using the linear regression model, <code>lin_model</code>, fitted in the previous task, predict the excess returns on <code>test_data</code>. Convert the excess returns into absolute returns by adding back the risk-free rate (column "RF"). Store the absolute return predictions as a new column in <code>test_data</code> called "FamaFrenchPredictions".
#     <br><br>
#     The resulting <code>test_data</code> should look similar to the following:
#
# ![Task_4_Data.JPG](attachment:Task_4_Data.JPG)
#     <p style="text-align:right;">[10pts]</p>
#     </div>
# </div>

# %%
test_data['FamaFrenchPredictions'] = lin_model.predict(test_data[factors]) + test_data['RF']
test_data
# Out:
#              ERP   SMB   HML   RMW   CMA     RF       Price   Returns  \
# Date
# 2019-04-30 -0.04 -0.67  0.25  0.09  0.70  0.010  197.542618 -1.944398
# 2019-05-01 -0.83 -0.08 -0.06  0.37 -0.03  0.009  207.239120  4.791895
# 2019-05-02 -0.16  0.48 -0.49  0.08  0.06  0.009  205.890457 -0.652903
# 2019-05-03  1.13  0.94 -0.27  0.01 -0.36  0.009  208.449951  1.235470
# 2019-05-06 -0.39  0.59 -0.45  0.01  0.05  0.009  205.230911 -1.556323
# ...          ...   ...   ...   ...   ...    ...         ...       ...
# 2020-04-24  1.44  0.29 -0.09 -0.14  0.16  0.000  282.206085  2.846075
# 2020-04-27  1.73  2.20  2.74 -0.12  0.20  0.000  282.405548  0.070655
# 2020-04-28 -0.44  1.65  2.89  1.39  0.74  0.000  277.827911 -1.634225
# 2020-04-29  2.92  2.27  2.04  1.22 -0.81  0.000  286.953247  3.231740
# 2020-04-30 -1.18 -2.06 -1.63  0.71 -0.10  0.000  293.006836  2.087664
#
#             ExcessReturns  FamaFrenchPredictions
# Date
# 2019-04-30      -1.954398              -0.787903
# 2019-05-01       4.782895              -0.846855
# 2019-05-02      -0.661903              -0.004328
# 2019-05-03       1.226470               1.689720
# 2019-05-06      -1.565323              -0.262591
# ...                   ...                    ...
# 2020-04-24       2.846075               1.479744
# 2020-04-27       0.070655               0.198864
# 2020-04-28      -1.634225              -2.971378
# 2020-04-29       3.231740               2.651375
# 2020-04-30       2.087664              -0.275422
#
# [254 rows x 10 columns]

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 5</b>
#     </div>
#     <div class = "panel-body">
#      We will now train a nueral network on the same to compare its performance. Recall that we first need to convert the data into tensors using the function <code>tf.convert_to_tensor()</code>. Set-up variables <code>X_train</code>, <code>X_test</code>, <code>y_train</code>, <code>y_test</code> to store the corresponding data from <code>train_data</code> and <code>test_data</code> as tensors.
#     <br><br>
#     The 4 tensors should have the following shapes:
#     <ul>
#         <li><code>X_train.shape = TensorShape([9675, 5])</code></li>
#         <li><code>X_test.shape = TensorShape([254, 5])</code></li>
#         <li><code>y_train.shape = TensorShape([9675])</code></li>
#         <li><code>y_test.shape = TensorShape([254])</code></li>
#     </ul>
#     <p style="text-align:right;">[5pts]</p>
#     </div>
# </div>

# %%
X_train = tf.convert_to_tensor(train_data[factors])
y_train = tf.convert_to_tensor(train_data['ExcessReturns'])
X_test = tf.convert_to_tensor(test_data[factors])
y_test = tf.convert_to_tensor(test_data['ExcessReturns'])
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (TensorShape([9675, 5]),
#  TensorShape([254, 5]),
#  TensorShape([9675]),
#  TensorShape([254]))

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 6</b>
#     </div>
#     <div class = "panel-body">
#     Create a neural network model with the following architecture (recall this is done using the tensor flow function <code>tf.keras.models.Sequential()</code>), and store this in a variable called <code>nnet_model</code>:
#     <ul>
#         <li>A hidden layer with 16 nodes and ReLU activation function, with L1 regularization applied to both the weights and biases with the coefficient set to 0.001.</li>
#         <li>Apply dropout to the first hidden layer with a 10% dropout rate.</li>
#         <li>A second hidden layer with 32 nodes and ReLU activation function, with L1 regularization applied to both the weights and biases with the coefficient set to 0.001.</li>
#         <li>Apply dropout to the second hidden layer with a 10% dropout rate.</li>
#         <li>An output layer with 1 node, since we are predicting only one target variable.</li>
#     </ul>
#     Hint, to apply L1 regularization pass the following parameters to the <code>tf.keras.layers.Dense()</code> function:
#     <ul>
#         <li><code>kernel_regularizer = tf.keras.regularizers.L1(0.001)</code></li>
#         <li><code>bias_regularizer = tf.keras.regularizers.L1(0.001)</code></li>
#     </ul>
#     <p style="text-align:right;">[15pts]</p>
#     </div>
# </div>

# %%
nnet_model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, activation = 'relu', 
                          kernel_regularizer = tf.keras.regularizers.L1(.001), 
                          bias_regularizer = tf.keras.regularizers.L1(.001)),
    tf.keras.layers.Dropout(.1),
    tf.keras.layers.Dense(32, activation = 'relu', 
                          kernel_regularizer = tf.keras.regularizers.L1(.001), 
                          bias_regularizer = tf.keras.regularizers.L1(.001)),
    tf.keras.layers.Dropout(.1),
    tf.keras.layers.Dense(1),
])

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 7</b>
#     </div>
#     <div class = "panel-body">
#     Configure the tensorflow model compilier for <code>nnet_model</code>, which will facilitate the training of our nueral network. Recall that this is done by calling the <code>.compile()</code> method of the neural network model object.
#     <br><br>
#     The two parameters we will need to configure in are:
#     <ul>
#         <li><code>loss</code>: Since we are training a regression model, the tensorflow loss function to use here is <code>tf.keras.losses.MeanSquaredError()</code>. </li>
#         <li><code>optimizer</code>: Use Adam as the optimizer, tensorflow function is <code>tf.keras.optimizers.Adam()</code>. Set the learning rate equal to 0.00005.</li>
#     </ul>
#     <p style="text-align:right;">[10pts]</p>
#     </div>
# </div>

# %%
loss_fx = tf.keras.losses.MeanSquaredError()
opt = tf.keras.optimizers.Adam(learning_rate = .00005)

nnet_model.compile(optimizer = opt, loss = loss_fx)

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 8</b>
#     </div>
#     <div class = "panel-body">
#     Now we will train the neural network. Recall that this is done by calling the <code>.fit()</code> method of the neural network model object. Provide the method with the training data (<code>X_train</code> and <code>y_train</code>), as well as the following additional parameters:
#     <ul>
#         <li><code>validation_data = (X_test, y_test)</code>: this allows for the evaluation of model performance on the test data during training.</li>
#         <li><code>epochs = 200</code>: trains the model on 200 passes of the training data.</li>
#         <li><code>shuffle = True</code>: shuffles the training data in between each epoch.</li>
#         <li><code>batch_size = 200</code>: sets the batch size to 200 samples under each iteration.</li>
#     </ul>
#     Plot both the training loss and test loss on a single line plot. Label the axes and provide a legend. Your plot should look similar to the following:
#
# ![Task_8_Plot.JPG](attachment:Task_8_Plot.JPG)
#     <p style="text-align:right;">[15pts]</p>
#     </div>
# </div>

# %%
history = nnet_model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 200, 
                         shuffle = True, batch_size = 200)
# Out:
# Epoch 1/200
# 49/49 [==============================] - 1s 6ms/step - loss: 8.9485 - val_loss: 7.9098
# Epoch 2/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.8613 - val_loss: 7.6868
# Epoch 3/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.7964 - val_loss: 7.4708
# Epoch 4/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.7655 - val_loss: 7.2520
# Epoch 5/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.6424 - val_loss: 7.0595
# Epoch 6/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.6235 - val_loss: 6.8673
# Epoch 7/200
# 49/49 [==============================] - 0s 3ms/step - loss: 8.5125 - val_loss: 6.6742
# Epoch 8/200
# 49/49 [==============================] - 0s 3ms/step - loss: 8.4773 - val_loss: 6.4865
# Epoch 9/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.3995 - val_loss: 6.2965
# Epoch 10/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.3403 - val_loss: 6.1134
# Epoch 11/200
# 49/49 [==============================] - 0s 3ms/step - loss: 8.2333 - val_loss: 5.9422
# Epoch 12/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.1877 - val_loss: 5.7614
# Epoch 13/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.1696 - val_loss: 5.5937
# Epoch 14/200
# 49/49 [==============================] - 0s 2ms/step - loss: 8.0390 - val_loss: 5.4250
# Epoch 15/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.9816 - val_loss: 5.2587
# Epoch 16/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.9495 - val_loss: 5.0998
# Epoch 17/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.8286 - val_loss: 4.9362
# Epoch 18/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.8167 - val_loss: 4.7720
# Epoch 19/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.7404 - val_loss: 4.6254
# Epoch 20/200
# 49/49 [==============================] - 0s 3ms/step - loss: 7.7035 - val_loss: 4.4750
# Epoch 21/200
# 49/49 [==============================] - 0s 4ms/step - loss: 7.6197 - val_loss: 4.3258
# Epoch 22/200
# 49/49 [==============================] - 0s 4ms/step - loss: 7.5700 - val_loss: 4.1829
# Epoch 23/200
# 49/49 [==============================] - 0s 5ms/step - loss: 7.4992 - val_loss: 4.0361
# Epoch 24/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.4271 - val_loss: 3.8997
# Epoch 25/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.3916 - val_loss: 3.7705
# Epoch 26/200
# 49/49 [==============================] - 0s 3ms/step - loss: 7.3098 - val_loss: 3.6441
# Epoch 27/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.2693 - val_loss: 3.5233
# Epoch 28/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.2357 - val_loss: 3.4096
# Epoch 29/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.1938 - val_loss: 3.2983
# Epoch 30/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.1524 - val_loss: 3.1975
# Epoch 31/200
# 49/49 [==============================] - 0s 3ms/step - loss: 7.1292 - val_loss: 3.0956
# Epoch 32/200
# 49/49 [==============================] - 0s 2ms/step - loss: 7.0943 - val_loss: 3.0045
# Epoch 33/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.9915 - val_loss: 2.9149
# Epoch 34/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.9815 - val_loss: 2.8364
# Epoch 35/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.9757 - val_loss: 2.7554
# Epoch 36/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.9191 - val_loss: 2.6820
# Epoch 37/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.9034 - val_loss: 2.6202
# Epoch 38/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.8872 - val_loss: 2.5615
# Epoch 39/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.8549 - val_loss: 2.5040
# Epoch 40/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.8319 - val_loss: 2.4517
# Epoch 41/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.8356 - val_loss: 2.3996
# Epoch 42/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.8444 - val_loss: 2.3625
# Epoch 43/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7556 - val_loss: 2.3149
# Epoch 44/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.7542 - val_loss: 2.2797
# Epoch 45/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7835 - val_loss: 2.2443
# Epoch 46/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7279 - val_loss: 2.2191
# Epoch 47/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7614 - val_loss: 2.1929
# Epoch 48/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7249 - val_loss: 2.1679
# Epoch 49/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6601 - val_loss: 2.1454
# Epoch 50/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7205 - val_loss: 2.1281
# Epoch 51/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7158 - val_loss: 2.1121
# Epoch 52/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6886 - val_loss: 2.0978
# Epoch 53/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7063 - val_loss: 2.0865
# Epoch 54/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6978 - val_loss: 2.0738
# Epoch 55/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6395 - val_loss: 2.0623
# Epoch 56/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7071 - val_loss: 2.0577
# Epoch 57/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.7015 - val_loss: 2.0495
# Epoch 58/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6556 - val_loss: 2.0418
# Epoch 59/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7059 - val_loss: 2.0346
# Epoch 60/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6637 - val_loss: 2.0276
# Epoch 61/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6385 - val_loss: 2.0230
# Epoch 62/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7070 - val_loss: 2.0218
# Epoch 63/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6756 - val_loss: 2.0176
# Epoch 64/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.7254 - val_loss: 2.0152
# Epoch 65/200
# 49/49 [==============================] - 0s 5ms/step - loss: 6.6671 - val_loss: 2.0128
# Epoch 66/200
# 49/49 [==============================] - 0s 5ms/step - loss: 6.6698 - val_loss: 2.0136
# Epoch 67/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.6135 - val_loss: 2.0126
# Epoch 68/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6446 - val_loss: 2.0093
# Epoch 69/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6443 - val_loss: 2.0094
# Epoch 70/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6285 - val_loss: 2.0072
# Epoch 71/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6253 - val_loss: 2.0040
# Epoch 72/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6379 - val_loss: 2.0052
# Epoch 73/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6590 - val_loss: 2.0072
# Epoch 74/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5978 - val_loss: 2.0070
# Epoch 75/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6720 - val_loss: 2.0077
# Epoch 76/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5977 - val_loss: 2.0077
# Epoch 77/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6551 - val_loss: 2.0078
# Epoch 78/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6720 - val_loss: 2.0146
# Epoch 79/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6365 - val_loss: 2.0155
# Epoch 80/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6269 - val_loss: 2.0150
# Epoch 81/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6644 - val_loss: 2.0116
# Epoch 82/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6339 - val_loss: 2.0134
# Epoch 83/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6007 - val_loss: 2.0132
# Epoch 84/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6512 - val_loss: 2.0119
# Epoch 85/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6612 - val_loss: 2.0170
# Epoch 86/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6331 - val_loss: 2.0117
# Epoch 87/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6295 - val_loss: 2.0119
# Epoch 88/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6055 - val_loss: 2.0150
# Epoch 89/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5815 - val_loss: 2.0186
# Epoch 90/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5939 - val_loss: 2.0213
# Epoch 91/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6196 - val_loss: 2.0223
# Epoch 92/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6018 - val_loss: 2.0258
# Epoch 93/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6626 - val_loss: 2.0261
# Epoch 94/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5657 - val_loss: 2.0247
# Epoch 95/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6324 - val_loss: 2.0284
# Epoch 96/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5991 - val_loss: 2.0275
# Epoch 97/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6286 - val_loss: 2.0307
# Epoch 98/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5783 - val_loss: 2.0282
# Epoch 99/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5987 - val_loss: 2.0295
# Epoch 100/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.7053 - val_loss: 2.0276
# Epoch 101/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6571 - val_loss: 2.0318
# Epoch 102/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6105 - val_loss: 2.0318
# Epoch 103/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6344 - val_loss: 2.0342
# Epoch 104/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5864 - val_loss: 2.0361
# Epoch 105/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6011 - val_loss: 2.0362
# Epoch 106/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6654 - val_loss: 2.0399
# Epoch 107/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6079 - val_loss: 2.0447
# Epoch 108/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5520 - val_loss: 2.0390
# Epoch 109/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.6085 - val_loss: 2.0369
# Epoch 110/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5468 - val_loss: 2.0365
# Epoch 111/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5774 - val_loss: 2.0354
# Epoch 112/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5709 - val_loss: 2.0373
# Epoch 113/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5699 - val_loss: 2.0370
# Epoch 114/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5811 - val_loss: 2.0396
# Epoch 115/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5999 - val_loss: 2.0345
# Epoch 116/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5897 - val_loss: 2.0355
# Epoch 117/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5987 - val_loss: 2.0330
# Epoch 118/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5658 - val_loss: 2.0347
# Epoch 119/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6116 - val_loss: 2.0315
# Epoch 120/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6127 - val_loss: 2.0346
# Epoch 121/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5704 - val_loss: 2.0355
# Epoch 122/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6067 - val_loss: 2.0355
# Epoch 123/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5952 - val_loss: 2.0364
# Epoch 124/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6063 - val_loss: 2.0346
# Epoch 125/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5747 - val_loss: 2.0359
# Epoch 126/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5526 - val_loss: 2.0390
# Epoch 127/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5659 - val_loss: 2.0386
# Epoch 128/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5956 - val_loss: 2.0415
# Epoch 129/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5488 - val_loss: 2.0383
# Epoch 130/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5413 - val_loss: 2.0336
# Epoch 131/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5616 - val_loss: 2.0330
# Epoch 132/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5726 - val_loss: 2.0329
# Epoch 133/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5586 - val_loss: 2.0278
# Epoch 134/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5806 - val_loss: 2.0274
# Epoch 135/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6097 - val_loss: 2.0287
# Epoch 136/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5538 - val_loss: 2.0286
# Epoch 137/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6008 - val_loss: 2.0271
# Epoch 138/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5805 - val_loss: 2.0299
# Epoch 139/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5816 - val_loss: 2.0316
# Epoch 140/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5442 - val_loss: 2.0334
# Epoch 141/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5645 - val_loss: 2.0329
# Epoch 142/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5531 - val_loss: 2.0299
# Epoch 143/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5935 - val_loss: 2.0289
# Epoch 144/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5893 - val_loss: 2.0299
# Epoch 145/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.6021 - val_loss: 2.0353
# Epoch 146/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5269 - val_loss: 2.0322
# Epoch 147/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5811 - val_loss: 2.0317
# Epoch 148/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5554 - val_loss: 2.0336
# Epoch 149/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.6220 - val_loss: 2.0297
# Epoch 150/200
# 49/49 [==============================] - 0s 5ms/step - loss: 6.5340 - val_loss: 2.0341
# Epoch 151/200
# 49/49 [==============================] - 0s 5ms/step - loss: 6.5763 - val_loss: 2.0344
# Epoch 152/200
# 49/49 [==============================] - 0s 5ms/step - loss: 6.5381 - val_loss: 2.0322
# Epoch 153/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5848 - val_loss: 2.0319
# Epoch 154/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5942 - val_loss: 2.0266
# Epoch 155/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5400 - val_loss: 2.0306
# Epoch 156/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5886 - val_loss: 2.0288
# Epoch 157/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5346 - val_loss: 2.0256
# Epoch 158/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5773 - val_loss: 2.0273
# Epoch 159/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5525 - val_loss: 2.0249
# Epoch 160/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5740 - val_loss: 2.0264
# Epoch 161/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5739 - val_loss: 2.0249
# Epoch 162/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5592 - val_loss: 2.0236
# Epoch 163/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5610 - val_loss: 2.0230
# Epoch 164/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5398 - val_loss: 2.0271
# Epoch 165/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5765 - val_loss: 2.0220
# Epoch 166/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5829 - val_loss: 2.0241
# Epoch 167/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5649 - val_loss: 2.0228
# Epoch 168/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5083 - val_loss: 2.0265
# Epoch 169/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5682 - val_loss: 2.0356
# Epoch 170/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5505 - val_loss: 2.0330
# Epoch 171/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5436 - val_loss: 2.0285
# Epoch 172/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5381 - val_loss: 2.0287
# Epoch 173/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5151 - val_loss: 2.0288
# Epoch 174/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5584 - val_loss: 2.0257
# Epoch 175/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5761 - val_loss: 2.0312
# Epoch 176/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5360 - val_loss: 2.0303
# Epoch 177/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5271 - val_loss: 2.0346
# Epoch 178/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.6140 - val_loss: 2.0331
# Epoch 179/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5532 - val_loss: 2.0305
# Epoch 180/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5166 - val_loss: 2.0301
# Epoch 181/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5300 - val_loss: 2.0323
# Epoch 182/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5091 - val_loss: 2.0295
# Epoch 183/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5308 - val_loss: 2.0316
# Epoch 184/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5670 - val_loss: 2.0281
# Epoch 185/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5635 - val_loss: 2.0297
# Epoch 186/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5524 - val_loss: 2.0288
# Epoch 187/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5541 - val_loss: 2.0294
# Epoch 188/200
# 49/49 [==============================] - 0s 5ms/step - loss: 6.5909 - val_loss: 2.0277
# Epoch 189/200
# 49/49 [==============================] - 0s 4ms/step - loss: 6.5058 - val_loss: 2.0302
# Epoch 190/200
# 49/49 [==============================] - 0s 6ms/step - loss: 6.5607 - val_loss: 2.0256
# Epoch 191/200
# 49/49 [==============================] - 0s 5ms/step - loss: 6.4905 - val_loss: 2.0270
# Epoch 192/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5187 - val_loss: 2.0276
# Epoch 193/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5343 - val_loss: 2.0253
# Epoch 194/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5184 - val_loss: 2.0227
# Epoch 195/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5572 - val_loss: 2.0231
# Epoch 196/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5427 - val_loss: 2.0257
# Epoch 197/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5614 - val_loss: 2.0236
# Epoch 198/200
# 49/49 [==============================] - 0s 2ms/step - loss: 6.5839 - val_loss: 2.0276
# Epoch 199/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5579 - val_loss: 2.0250
# Epoch 200/200
# 49/49 [==============================] - 0s 3ms/step - loss: 6.5298 - val_loss: 2.0247

# %%
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 9</b>
#     </div>
#     <div class = "panel-body">
#     Calculate the excess return predictions from the neural network <code>nnet_model</code> on the test dataset <code>X_test</code>, and remember to convert the predictions from a tensor back into a numpy array. Recall, use the <code>.numpy()</code> method to turn tensors into numpy arrays.
#     <br><br>
#     Calculate the absolute return predictions by adding back the risk-free rate (column "RF"), and store them as a new column in <code>test_data</code> called "NeuralNetPredictions".
#     <br><br>
#     The resulting <code>test_data</code> should look similar to the following:
#
# ![Task_9_Data.JPG](attachment:Task_9_Data.JPG)
#     <p style="text-align:right;">[10pts]</p>
#     </div>
# </div>

# %%
pred = nnet_model(X_test).numpy()
test_data['NeuralNetPredictions'] = pred.flatten() + test_data['RF']
test_data
# Out:
#              ERP   SMB   HML   RMW   CMA     RF       Price   Returns  \
# Date
# 2019-04-30 -0.04 -0.67  0.25  0.09  0.70  0.010  197.542618 -1.944398
# 2019-05-01 -0.83 -0.08 -0.06  0.37 -0.03  0.009  207.239120  4.791895
# 2019-05-02 -0.16  0.48 -0.49  0.08  0.06  0.009  205.890457 -0.652903
# 2019-05-03  1.13  0.94 -0.27  0.01 -0.36  0.009  208.449951  1.235470
# 2019-05-06 -0.39  0.59 -0.45  0.01  0.05  0.009  205.230911 -1.556323
# ...          ...   ...   ...   ...   ...    ...         ...       ...
# 2020-04-24  1.44  0.29 -0.09 -0.14  0.16  0.000  282.206085  2.846075
# 2020-04-27  1.73  2.20  2.74 -0.12  0.20  0.000  282.405548  0.070655
# 2020-04-28 -0.44  1.65  2.89  1.39  0.74  0.000  277.827911 -1.634225
# 2020-04-29  2.92  2.27  2.04  1.22 -0.81  0.000  286.953247  3.231740
# 2020-04-30 -1.18 -2.06 -1.63  0.71 -0.10  0.000  293.006836  2.087664
#
#             ExcessReturns  FamaFrenchPredictions  NeuralNetPredictions
# Date
# 2019-04-30      -1.954398              -0.787903             -0.680350
# 2019-05-01       4.782895              -0.846855             -0.947592
# 2019-05-02      -0.661903              -0.004328             -0.142815
# 2019-05-03       1.226470               1.689720              1.626555
# 2019-05-06      -1.565323              -0.262591             -0.323053
# ...                   ...                    ...                   ...
# 2020-04-24       2.846075               1.479744              1.489118
# 2020-04-27       0.070655               0.198864              0.305755
# 2020-04-28      -1.634225              -2.971378             -2.813235
# 2020-04-29       3.231740               2.651375              2.149789
# 2020-04-30       2.087664              -0.275422             -0.260495
#
# [254 rows x 11 columns]

# %% [markdown]
# <div class = "panel panel-primary">
#     <div class = "panel-heading">
#     <span style="color:white"><b>Task 10</b>
#     </div>
#     <div class = "panel-body">
#     Plot in a single line plot the following from <code>test_data</code>:
#     <ul>
#         <li>The historical Apple stock <b>price</b>.</li>
#         <li>The linear regression model's predicted Apple stock <b>price</b>.</li>
#         <li>The neural network's predicted Apple stock <b>price</b>.</li>
#     </ul>
#     Include a legend. The final plot should look similar to the following (it will not be exactly the same due to variations in initial parameters used at the start of neural network training):
#
# ![Task_9_Plot.JPG](attachment:Task_9_Plot.JPG)
#     <p style="text-align:right;">[10pts]</p>
#     </div>
# </div>

# %%
plt.figure(figsize = (12, 5))
plt.plot(test_data['Price'], label = 'Historical')
plt.plot(test_data.loc['2019-04-30', 'Price'] * np.exp(np.cumsum((test_data['FamaFrenchPredictions'] + test_data['RF']) / 100.)), label = 'Fama-French')
plt.plot(test_data.loc['2019-04-30', 'Price'] * np.exp(np.cumsum((test_data['NeuralNetPredictions'] + test_data['RF']) / 100.)), label = 'Neural Net')
plt.legend()
plt.show()
